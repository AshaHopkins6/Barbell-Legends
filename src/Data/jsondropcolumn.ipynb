# %%
pip install pandas
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_json('lifting1.json')
df
# Out:
#                    Name Sex Event   Equipment Age AgeClass Division  \
# 0           PJ Mardesic   M   SBD       Wraps  33    24-34     M-OR
# 1         Jamie Bradnam   M   SBD       Wraps  27    24-34     M-OR
# 2    Nathaniel Williams   M   SBD  Single-ply                  Boys
# 3           Alyson Shaw   F   SBD       Wraps  23    20-23     F-OR
# 4          Brenda Brown   F   SBD       Wraps  35    35-39     F-OR
# ..                  ...  ..   ...         ...  ..      ...      ...
# 143     Colleen Houngan   F   SBD       Wraps  53    50-54     F-OR
# 144   Annalicia Vaughan   F   SBD       Wraps  28    24-34     F-OR
# 145        Ellen Hooper   F   SBD       Wraps  14    13-15     F-OR
# 146     Patricia Liebke   F   SBD       Wraps  42    40-44     F-OR
# 147      Sam Kettlewell   F   SBD       Wraps  29    24-34     F-OR
#
#      BodyweightKg WeightClassKg Squat1Kg  ... McCulloch Glossbrenner  \
# 0           93.60           100      160  ...    316.28       304.51
# ...

# %%
df = df.set_index('Name')
df
# Out:
#                    Sex Event   Equipment Age AgeClass Division  BodyweightKg  \
# Name
# PJ Mardesic          M   SBD       Wraps  33    24-34     M-OR         93.60
# Jamie Bradnam        M   SBD       Wraps  27    24-34     M-OR         99.10
# Nathaniel Williams   M   SBD  Single-ply                  Boys         58.24
# Alyson Shaw          F   SBD       Wraps  23    20-23     F-OR         56.70
# Brenda Brown         F   SBD       Wraps  35    35-39     F-OR         59.20
# ...                 ..   ...         ...  ..      ...      ...           ...
# Colleen Houngan      F   SBD       Wraps  53    50-54     F-OR         73.50
# Annalicia Vaughan    F   SBD       Wraps  28    24-34     F-OR         80.90
# Ellen Hooper         F   SBD       Wraps  14    13-15     F-OR         80.70
# Patricia Liebke      F   SBD       Wraps  42    40-44     F-OR         88.80
# Sam Kettlewell       F   SBD       Wraps  29    24-34     F-OR        106.90
#
# ...

# %%
df = df.drop(['Age',  'BodyweightKg', 'Squat1Kg', 'Squat2Kg', 'Squat3Kg', 'Squat4Kg', 'Bench1Kg', 'Bench2Kg', 'Bench3Kg', 'Bench4Kg', 'Deadlift1Kg', 'Deadlift2Kg', 'Deadlift3Kg', 'Deadlift4Kg'], axis=1)
df
# Out:
#                    Sex Event   Equipment AgeClass Division WeightClassKg  \
# Name
# PJ Mardesic          M   SBD       Wraps    24-34     M-OR           100
# Jamie Bradnam        M   SBD       Wraps    24-34     M-OR           100
# Nathaniel Williams   M   SBD  Single-ply              Boys          59.8
# Alyson Shaw          F   SBD       Wraps    20-23     F-OR            60
# Brenda Brown         F   SBD       Wraps    35-39     F-OR            60
# ...                 ..   ...         ...      ...      ...           ...
# Colleen Houngan      F   SBD       Wraps    50-54     F-OR            75
# Annalicia Vaughan    F   SBD       Wraps    24-34     F-OR          82.5
# Ellen Hooper         F   SBD       Wraps    13-15     F-OR          82.5
# Patricia Liebke      F   SBD       Wraps    40-44     F-OR            90
# Sam Kettlewell       F   SBD       Wraps    24-34     F-OR           110
#
#                    Best3SquatKg Best3BenchKg Best3DeadliftKg TotalKg  ...  \
# ...

# %%
df.to_csv(r'/Users/ashahopkins/Desktop/BarbellLegends/Website/barbell-legends/src/Data/data.csv')

# %%
import csv 
import json 

def csv_to_json(csvFilePath, jsonFilePath):
    jsonArray = []
      
    #read csv file
    with open(csvFilePath, encoding='utf-8') as csvf: 
        #load csv file data using csv library's dictionary reader
        csvReader = csv.DictReader(csvf) 

        #convert each csv row into python dict
        for row in csvReader: 
            #add this python dict to json array
            jsonArray.append(row)
  
    #convert python jsonArray to JSON String and write to file
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
        jsonString = json.dumps(jsonArray, indent=4)
        jsonf.write(jsonString)
          
csvFilePath = r'/Users/ashahopkins/Desktop/BarbellLegends/Website/barbell-legends/src/Data/data.csv'
jsonFilePath = r'cleanedData.json'
csv_to_json(csvFilePath, jsonFilePath)
